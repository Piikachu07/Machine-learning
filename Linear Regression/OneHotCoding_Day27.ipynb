# %%
import pandas as pd

# %%
data = pd.read_csv('cars.csv')

# %%
data.sample(5)
# Out:
#          brand  km_driven    fuel         owner  selling_price
# 6529   Hyundai     103655  Diesel  Second Owner         400000
# 3258    Maruti      60000  Petrol   First Owner         210000
# 1833      Tata      35000  Diesel   First Owner         259000
# 5081    Maruti      70000  Diesel  Second Owner         800000
# 1498  Mahindra      80000  Diesel   Third Owner         590000

# %%
data['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
data['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
data['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# # One hotencoding with Pandas

# %%
pd.get_dummies(data,columns=['fuel','owner'],drop_first=True, dtype = int) #here I had dropped the first dummy column as it creates multilinearity problem
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                              0                   0                     0
# 1                              0                   1                     0
# 2                              0                   0                     0
# 3                              0                   0                     0
# 4                              0                   0                     0
# ...                          ...                 ...                   ...
# 8123                           0                   0                     0
# 8124                           1                   0                     0
# 8125                           0                   0                     0
# 8126                           0                   0                     0
# 8127                           0                   0                     0
#
#       owner_Third Owner
# 0                     0
# 1                     0
# 2                     1
# 3                     0
# 4                     0
# ...                 ...
# 8123                  0
# 8124                  0
# 8125                  0
# 8126                  0
# 8127                  0
#
# [8128 rows x 10 columns]

# %% [markdown]
# # one hotencoding using sklearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,0:4],data.iloc[:,-1],test_size = 0.2, random_state=2)

# %%
X_train
# Out:
#          brand  km_driven    fuel         owner
# 5571   Hyundai      35000  Diesel   First Owner
# 2038      Jeep      60000  Diesel   First Owner
# 2957   Hyundai      25000  Petrol   First Owner
# 7618  Mahindra     130000  Diesel  Second Owner
# 6684   Hyundai     155000  Diesel   First Owner
# ...        ...        ...     ...           ...
# 3606      Ford      35000  Diesel   First Owner
# 5704    Maruti     120000  Petrol   First Owner
# 6637      Tata      15000  Petrol   First Owner
# 2575    Maruti      32500  Diesel  Second Owner
# 7336     Isuzu     121000  Diesel   First Owner
#
# [6502 rows x 4 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
ohe = OneHotEncoder(drop = 'first', sparse_output = False, dtype =np.int32)

# %%
X_train_scaled = ohe.fit_transform(X_train[['fuel','owner']])

# %%
X_train_scaled.shape
# Out:
# (6502, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_scaled))
# Out:
# array([['Hyundai', 35000, 1, ..., 0, 0, 0],
#        ['Jeep', 60000, 1, ..., 0, 0, 0],
#        ['Hyundai', 25000, 0, ..., 0, 0, 0],
#        ...,
#        ['Tata', 15000, 0, ..., 0, 0, 0],
#        ['Maruti', 32500, 1, ..., 1, 0, 0],
#        ['Isuzu', 121000, 1, ..., 0, 0, 0]], dtype=object)

# %% [markdown]
# # onehotencoding with top categories

# %%
tcount =data['brand'].value_counts()

# %%
data['brand'].nunique()
thresold = 100

# %%
replace =tcount[tcount<=thresold].index

# %%
pd.get_dummies(data['brand'].replace(replace, 'uncommon'), sparse = False, drop_first = True, dtype = np.int32 ).sample(5)
# Out:
#       Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  Tata  \
# 2849          0     0      0        0         0       1        0      0     0
# 3375          1     0      0        0         0       0        0      0     0
# 7685          0     0      0        0         0       0        0      0     1
# 7171          0     0      0        0         0       0        0      0     1
# 5935          0     0      0        0         0       0        0      0     0
#
#       Toyota  Volkswagen  uncommon
# 2849       0           0         0
# 3375       0           0         0
# 7685       0           0         0
# 7171       0           0         0
# 5935       1           0         0
